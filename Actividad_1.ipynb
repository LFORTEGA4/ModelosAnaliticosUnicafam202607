# %% [markdown]
# <a href="https://colab.research.google.com/github/LFORTEGA4/ModelosAnaliticosUnicafam202607/blob/main/Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CLASE: MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: LUISA ORTEGA

# %% [markdown]
# # VARIABLES

# %%
var= "hola mundo"
print(var)
# Out:
# hola mundo

# %%
#1. LAS VARIABLES DEBEN SER EN MINUSCULA
#2. LAS VARIABLES NO DEBEN TENER ESPACIOS
#3. LAS VARIABLES NO DEBEN CONTENER CARACTERES ESPECIALES

# %%
n

# %% [markdown]
# ## TIPOS DE DATOS

# %%
# ENTEROS
entero=5
entero_explicito=int(5)

# DECIMALES
decimal=5.0
decimal_explicito=float(5.0)

# %%
type(entero)
# Out:
# int

# %% [markdown]
# OPERADORES MATEMATICOS

# %% [markdown]
# ## VARIABLE SUMA

# %%
a=10
b=3
print(a+b)
# Out:
# 13

# %% [markdown]
# #VARIABLE RESTA

# %%
a=10
b=3
c=a-b
print(c)
# Out:
# 7

# %% [markdown]
# ## VARIABLE MULTIPLICACION

# %%
a=10
b=3
print(a*b)
# Out:
# 30

# %% [markdown]
# ## VARIABLE DIVISION

# %%
a=10
b=3
print(a/b)
# Out:
# 3.3333333333333335

# %%
# DIVISION ENTERA
print(a//b)
# Out:
# 3

# %%
# MODULO
print(a%b)
# Out:
# 1

# %%
# EXPONENCIACION
print(b**2)
# Out:
# 9

# %% [markdown]
# ## VALORES DE CADENA

# %%
cadena="Hola, mundo!"
print(cadena [0])
# Out:
# H

# %%
# EXTRAER LA PALABRA MUNDO
print(cadena[6:11])
# Out:
# mundo

# %%
# CONQUETACION DE VALORES
palabra1="¿como"
palabra2="estas?"
print(palabra1+" ,"+palabra2)
# Out:
# ¿como ,estas?

# %% [markdown]
# #SALUDO COMPLETO

# %%
# Saludo completo
print(cadena[0:18]+" "+palabra1+" ,"+palabra2)
# Out:
# Hola, mundo! ¿como ,estas?

# %% [markdown]
# #SALUDO MAYÚSCULAS

# %%
# CAMBIOS DE FORMATO
print((cadena+ " "+palabra1+" ,"+palabra2).upper())
# Out:
# HOLA, MUNDO! ¿COMO ,ESTAS?

# %% [markdown]
# #SALUDO REEMPLAZO

# %%
# SALUDO_REEMPLAZO
palabra3="python"
print(cadena[0:6]+palabra3+cadena[11]+" "+palabra1+" ,"+palabra2)
# Out:
# Hola, python! ¿como ,estas?
