# %% [markdown]
# <a href="https://colab.research.google.com/github/LFORTEGA4/ModelosAnaliticosUnicafam202607/blob/main/CLASE_2_Luisa_Ortega.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTAS

# %% [markdown]
# # ESTRUCTURAS DE DATOS
#
# MODELOS ANALITICOS
#
# UNICAFAM
#
# DOCENTE: NICOLAS MOJICA
#
# ESTUDIANTE: LUISA ORTEGA

# %%
# UNA LISTA VACIA
mi_lista=[]
# lista con varios elementos
mi_lista=[1,2,3,"4",5.0,True]
print(mi_lista[2])
# Out:
# 3

# %%
# cambios en la lista
mi_lista[0]="Luisa"
print(mi_lista)
# Out:
# ['Luisa', 2, 3, '4', 5.0, True]

# %%
# Agregar eñementos a una lista
mi_lista.append("Ortega")
print(mi_lista)
# Out:
# ['Luisa', 2, 3, '4', 5.0, True, 'Ortega']

# %%
# Agregar elementos a una posicion
mi_lista.insert(3,"Medellin")
print(mi_lista)
# Out:
# ['Luisa', 2, 3, 'Medellin', '4', 5.0, True, 'Ortega']

# %%
# Agregar varios elementos
mi_lista.extend([7,False])
print(mi_lista)
# Out:
# ['Luisa', 2, 3, 'Medellin', '4', 5.0, True, 'Ortega', 7, False]

# %%
#Quitar elementos
#Eliminar obsjetos especificos
mi_lista.remove(True)
print(mi_lista)
# Out:
# ['Luisa', 2, 3, 'Medellin', '4', 5.0, 'Ortega', 7, False]

# %% [markdown]
# # DICCIONARIOS

# %%
mi_diccionario= {
    "Nombre":"Luisa",
    "Ciudad de nacimiento":"Medellin",
    "Empresa":"CAFAM"
}

# %%
 # Acceder a los elementos del diccionario
print(mi_diccionario ["Nombre"])
# Out:
# Luisa

# %%
# Modificar un valor en el diccionario
mi_diccionario["Nombre"]="Luisa Fernanda"
print(mi_diccionario)
# Out:
# {'Nombre': 'Luisa Fernanda', 'Ciudad de nacimiento': 'Medellin', 'Empresa': 'CAFAM'}

# %%
#Añadir un elemento al diccionario
mi_diccionario ["Profesion"]="Médico"
print(mi_diccionario)
# Out:
# {'Nombre': 'Luisa Fernanda', 'Ciudad de nacimiento': 'Medellin', 'Empresa': 'CAFAM', 'Profesion': 'Médico'}

# %%
# Eliminar un elemento del diccionario
del mi_diccionario["Ciudad de nacimiento"]
print(mi_diccionario)
# Out:
# {'Nombre': 'Luisa Fernanda', 'Empresa': 'CAFAM', 'Profesion': 'Médico'}

# %% [markdown]
# #CONDICIONALES

# %%
#Crea un programa que determine si una persona es mayor de edad
print("----VERIFICACIÓN DE EDAD----")
edad=int(input("Ingresa tu edad:"))
if edad<18:
  print(f"Eres menor de edad, tienes:{edad}")
else:
  print(f"Eres mayor de edad, tienes:{edad}")
# Out:
# ----VERIFICACIÓN DE EDAD----
# Ingresa tu edad:30
# Eres mayor de edad, tienes:30

# %%
#Crea un programa que determine si una persona es mayor de edad
print("----VERIFICACIÓN DE EDAD----")
edad=int(input("Ingresa tu edad:"))
if edad<18:
  print(f"Eres menor de edad, tienes:{edad}")
else:
  print(f"Eres mayor de edad, tienes:{edad}")
# Out:
# ----VERIFICACIÓN DE EDAD----
# Ingresa tu edad:17
# Eres menor de edad, tienes:17

# %%
# Condicionales multiples
nota=50
if nota >=80:
  if nota >=90:
    print("Excelente")
  elif nota>=80 and nota<90:
    print("Aceptable")
else:
  print("Insuficiente")
# Out:
# Insuficiente
