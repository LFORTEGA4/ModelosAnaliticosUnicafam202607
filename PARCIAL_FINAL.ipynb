# %% [markdown]
# <a href="https://colab.research.google.com/github/LFORTEGA4/ModelosAnaliticosUnicafam202607/blob/main/PARCIAL_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PARCIAL FINAL
#
# Diplomado analitica de datos
#
# docente: Nicolas mojica
#
# Estudiante: Luisa Fernanda Ortega

# %%
# Paso 1. Importar librerias

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# paso 2 importar set de datos
dataset = pd.read_csv ("/content/sample_data/crime_data(in).csv")

# %%
# paso 3 seleccionar variables a determinar
features = ["Murder", "Assault", "UrbanPop", "Rape"]
X = dataset[features]

# %%
X
# Out:
#     Murder  Assault  UrbanPop  Rape
# 0     13.2      236        58  21.2
# 1     10.0      263        48  44.5
# 2      8.1      294        80  31.0
# 3      8.8      190        50  19.5
# 4      9.0      276        91  40.6
# 5      7.9      204        78  38.7
# 6      3.3      110        77  11.1
# 7      5.9      238        72  15.8
# 8     15.4      335        80  31.9
# 9     17.4      211        60  25.8
# 10     5.3       46        83  20.2
# 11     2.6      120        54  14.2
# 12    10.4      249        83  24.0
# 13     7.2      113        65  21.0
# 14     2.2       56        57  11.3
# 15     6.0      115        66  18.0
# 16     9.7      109        52  16.3
# 17    15.4      249        66  22.2
# 18     2.1       83        51   7.8
# 19    11.3      300        67  27.8
# 20     4.4      149        85  16.3
# 21    12.1      255        74  35.1
# 22     2.7       72        66  14.9
# 23    16.1      259        44  17.1
# 24     9.0      178        70  28.2
# ...

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1, 11):
 kmeans= KMeans(n_clusters=i, init="k-means++", random_state=42, n_init=10)
 kmeans.fit(X_scaled)
 wcss.append(kmeans.inertia_)


# Grafica del codo
plt.plot(range(1, 11), wcss)
plt.title("Grafica del codo")
plt.ylabel("variacion")
plt.xlabel("clusters")
# Out:
# Text(0.5, 0, 'clusters')

# %%
# Entrenamiento del modelo de clusterizacion
kmeans= KMeans(n_clusters=4,init="k-means++", random_state=42)
y_kmeans=kmeans.fit_predict(X)

# %%
# resultados


plt.scatter(X.loc[y_kmeans == 0, features[0]], X.loc[y_kmeans == 0, features[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X.loc[y_kmeans == 1, features[0]], X.loc[y_kmeans == 1, features[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X.loc[y_kmeans == 2, features[0]], X.loc[y_kmeans == 2, features[1]], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X.loc[y_kmeans == 3, features[0]], X.loc[y_kmeans == 3, features[1]], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters de Crímenes')
plt.xlabel(features[0])
plt.ylabel(features[1])
plt.legend()
plt.show()

# %%
dataset["Cluster"]= y_kmeans
dataset
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  Cluster
# 0          Alabama    13.2      236        58  21.2        1
# 1           Alaska    10.0      263        48  44.5        1
# 2          Arizona     8.1      294        80  31.0        1
# 3         Arkansas     8.8      190        50  19.5        2
# 4       California     9.0      276        91  40.6        1
# 5         Colorado     7.9      204        78  38.7        2
# 6      Connecticut     3.3      110        77  11.1        3
# 7         Delaware     5.9      238        72  15.8        1
# 8          Florida    15.4      335        80  31.9        1
# 9          Georgia    17.4      211        60  25.8        2
# 10          Hawaii     5.3       46        83  20.2        0
# 11           Idaho     2.6      120        54  14.2        3
# 12        Illinois    10.4      249        83  24.0        1
# 13         Indiana     7.2      113        65  21.0        3
# ...

# %% [markdown]
# # RESULTADOS

# %% [markdown]
# 1. Como podemos agrupar los estados?
#
# Utilizando un módelo Kmeans, donde previamente contamos con unos datos agrupados, donde se pueden clasificar por variables dado el delito cometido y los estados implicados en cada delito, asi mismo tratando de buscar centroide en cada cifra de cada variable.

# %% [markdown]
# 2. Cuáles son los estados con necesidad de profesionales con mayor capacidad de atención?
#
# Haciendo el corte analítico sobre este set de datos, los estados prioritarios son: Eje Sur y del Golfo: Alabama, Louisiana, Mississippi, North Carolina, South Carolina, Georgia, Florida y Tennessee.Grandes urbes / Áreas complejas: California, Nevada, New Mexico, Arizona, Maryland, Michigan, Illinois, New York, Texas, Nevada y Alaska.

# %% [markdown]
# 3. Como distribuiria los recursos?
#  - Bloque de Alta Complejidad (Aproximadamente 14-16 estados): Se les asigna de forma exclusiva el grupo de 300 policías capacitados para asaltos y asesinatos. Su entrenamiento especializado se concentra estrictamente donde ocurren los crímenes y delitos mayores.
# - Bloque de Complejidad Media (Aproximadamente 16-18 estados): Se despliegan los 500 policías. Estos estados tienen poblaciones urbanas muy densas (alta probabilidad de delincuencia común, raponazos y hurtos) pero con índices de homicidio controlados. Su presencia a pie disuade el delito callejero.
# - Bloque de Baja Complejidad (\(Aproximadamente 16-18 estados): Se asignan los 150 cadetes. Al ser zonas seguras, los cadetes atienden los requerimientos de baja complejidad.

# %% [markdown]
# 4. Cuales son los grupos que existen dentro del comportamiento de la criminalidad?
#  - Grupo 1: Crítico / Violencia Extrema: Caracterizado por tasas de homicidio alarmantes (superiores a 11 por cada 100mil habitantes)
# - Grupo 2: Urbano / Riesgo Moderado: Caracterizado por estados con alta concentración en ciudades (población urbana superior al 70%). Tienen problemas crónicos de hurtos y delincuencia común (raponazos).
# - Grupo 3: Seguro / Bajo Impacto: Estados predominantemente rurales y tranquilos (como North Dakota, Vermont o Iowa). Sus tasas de delincuencia están muy por debajo de la media nacional.

# %% [markdown]
# 5. Recomendaciones finales:
#
#  * Monitoreo Semestral: El comportamiento criminal cambia. Por lo que es de suma importancia realizar modelos analiticos en python (tipo cluster) para analisis de datos y adecuadas estrategias de acuerdo a la situacion actualizada.
#  * Proteger el Recurso Especializado: Prohibir el uso de los 300 policías capacitados en tareas de patrullaje general en estados seguros. Su tiempo debe enfocarse al 100% en operativos e investigación en el Grupo Crítico.
#  * Movilidad del Pie de Fuerza Urbano
#  * Estrategia de Relevo Gradual
